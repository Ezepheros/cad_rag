# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '..'))
from cad_rag.data.Dataset import CanadianCaseLawDocumentDatabase

import pyarrow.parquet as pq
import pandas as pd

# %%
file_name_base = "ONCA_embedded_chunked"
pq_name = file_name_base + ".parquet"
path = "/ubc/cs/research/nlp-raid/students/ethanz01/cad_rag/embedded_naive_chunked_data_ONCA_512-64_QWEN8B/"
pq_path = path + pq_name

# %%
df = pd.read_parquet(pq_path)
